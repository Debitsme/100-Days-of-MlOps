# %% [markdown]
# # Creating a Virtual Env

# %% [markdown]
# ``python3 -m venv /root/code/ml-env``

# %% [markdown]
# # Activating a virtual env in python

# %% [markdown]
# ``source ml-env/bin/activate``

# %% [markdown]
# # Install any dependencies

# %% [markdown]
# ``
# pip install numpy pandas``

# %% [markdown]
# # pip freeze command
# ### It allows the preservation of the existing packages and librarries into the requirement.py file

# %% [markdown]
# ``pip freeze > requirements.txt``
