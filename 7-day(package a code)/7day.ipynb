# %% [markdown]
# # creating a wheel in python
# wheel = packaging your code so others can install it with one command (pip install

# %% [markdown]
# do a sample project to build a python code to be installed as a package?
