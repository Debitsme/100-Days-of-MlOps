# %% [markdown]
# # How the structure of ML project should looks like

# %% [markdown]
# fraud-detection/
# ├── data/
# │   ├── raw/
# │   └── processed/
# ├── models/
# ├── notebooks/
# ├── src/
# │   ├── data/__init__.py
# │   ├── features/__init__.py
# │   ├── models/__init__.py
# │   └── utils/__init__.py
# ├── tests/
# ├── configs/
# ├── requirements.txt
# └── README.md
