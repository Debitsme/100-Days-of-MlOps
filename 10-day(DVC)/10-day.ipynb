# %% [markdown]
# #  DVC

# %% [markdown]
# How to initialize DVC
#
# ``DVC Init ``

# %% [markdown]
# # stage dvc changes
#
# ``git add .dvc/ .dvcignore .gitignore``

# %% [markdown]
# # stage dvc changes
#
# ``git commit -m "Initialize DVC"``
